# %%
#ESERCIZIO 1: Individuo tre task:

#A --> cucinare una bistecca
#1) metti la padella sul fornello
#2) accendi il fuoco
#3) aspetta che la padella si scaldi
#4) la padella è calda abbastanza? se no torna al punto 3
#5) metti la bistecca in padella
#6) attendi che il primo lato si cuocia
#7) il primo lato è cotto? se no torna al punto 6
#8) gira la bistecca
#9) attendi che il secondo lato si cuocia
#10) il secondo lato è cotto? se no torna al punto 9
#11) impiatta la bistecca

#B --> installare un videogioco sul PC
#1) scarica l'installer
#2) avvia l'installazione
#3) scegli il percorso di installazione
#4) c'è abbastanza spazio libero sull'hard disk? Se no vai al passaggio 5, altrimenti vai al passaggio 6
#5) libera spazio sull'hard disk, poi torna al punto 4
#6) concludi l'installazione
#7) avvia il gioco

#C --> inserire un'anagrafica cliente su un CRM
#1) inserisci una nuova anagrafica
#2) inserisci il nome
#3) inserisci il cognome
#4) inserisci il dominio del sito web
#5) il dominio ha già un'anagrafica associata? se si, vai al passaggio 6, altrimenti passa al 7
#6) mostra messaggio 'anagrafica già esistente' e torna al passaggio 4
#7) salva l'anagrafica

# %%
#ESERCIZIO 2: Abbiamo 25 studenti; memorizzare questo dato in una variabile.
students = 25

# %%
#ESERCIZIO 3: Abbiamo 25 studenti; memorizzare questo dato in una variabile e stamparla a video.
students = 25
print(students)
# Out:
# 25

# %%
#ESERCIZIO 4: Abbiamo 25 studenti; memorizzare questo dato in una variabile. Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile.
students = 25
newStudents = 28
print(newStudents)
# Out:
# 28

# %%
#ESERCIZIO 5: Abbiamo 25 studenti; memorizzare questo dato in una variabile. Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile.
#Creare un'altra variabile ancora che conterrà la somma delle prime due, poi stamparla a video.
students = 25
students += 3
print(students)
# Out:
# 28

# %%
#ESERCIZIO 6: Creare una variabile che contiene la stringa "Epicode", quindi stamparla a video.
school = 'Epicode'
print(school)
# Out:
# Epicode

# %%
#ESERCIZIO 7: Abbiamo la variabile: x = 10. Incrementarla di 2 e poi moltiplicarla per 3
x = 10
x += 2
x *= 3 #-----> domanda: posso inserire queste due opreazioni sulla stessa riga o devo fare due operazioni separate?
print(x)
# Out:
# 36

# %%
#ESERCIZIO 8: Creiamo le seguenti stringhe, e per ognuna di esse verifichiamone la lunghezza con la funzione len()
str1 = 'Windows'
str2 = 'Excel'
str3 = 'Powerpoint'
str4 = 'Word'

print(len(str1))
print(len(str2))
print(len(str3))
print(len(str4))
#-----> domanda: perchè nell'output non mi da tutti i risultati delle operazioni len ma solo uno alla volta? Risposta: perchè dovrei metterle in celle diverse oppure mettere print davanti a tutte
#altrimenti viene stampata solo l'ultima
# Out:
# 7
# 5
# 10
# 4

# %%
#ESERCIZIO 9: Calcolare e stampare a video quanti secondi ci sono in un anno non bisestile.
yearDays = 365
yearSeconds = 365 * 24 * 60 * 60
print('Secondi in un anno bisestile:', yearSeconds)
# Out:
# Secondi in un anno bisestile: 31536000

# %%
#ESERCIZIO 10: Abbiamo la seguente stringa: my_string = "I am studying Python"
#Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase
#Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase)
#Sostituire la sottostringa "Python" con la stringa "a lot"
#Usare il metodo .strip(); cambia qualcosa? Perché?
#Usare il metodo .split() per trovare tutte le parole (token)

my_string = "I am studying Python"
print(my_string.upper())
print(my_string.lower())
newString = my_string.replace('Python', 'a lot')
print(newString)
print(my_string.strip()) #non cambia nulla perchè strip rimuove spazi vuoti all'inizio e alla fine della stringa
print(my_string.split(' '))
print(my_string.split(' ')[-2]) # extra: ho provato a recuperare un valore della stringa tramite indexing
# Out:
# I AM STUDYING PYTHON
# i am studying python
# I am studying a lot
# I am studying Python
# ['I', 'am', 'studying', 'Python']
# studying

# %%
#ESERCIZIO 11: Abbiamo due liste, una di studenti e una di corsi:
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
#Tenendo conto che i dati sono in corrispondenza posizionale, leggiamo con attenzione le due liste.
#Sapendo che:
#Emma segue Data Analyst
#Faith segue Backend
#Grace segue Frontend
#Henry segue Cybersecurity
#alla lista cui mancano dei dati, aggiungiamo i dati mancanti uno alla volta con il metodo .append()

corsi.append('Frontend')
corsi.append('Cybersecurity')
print(studenti)
print(corsi)
# Out:
# ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry']
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
