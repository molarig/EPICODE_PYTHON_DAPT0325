# %%
studenti = ['Ada', 'Mark', 'Sarah', 'Luce', 'John', 'Paula']
studenti
# Out:
# ['Ada', 'Mark', 'Sarah', 'Luce', 'John', 'Paula']

# %%
studenti.append('Leo')
studenti
# Out:
# ['Ada', 'Mark', 'Sarah', 'Luce', 'John', 'Paula', 'Leo']

# %%
studenti
# Out:
# ['Ada', 'Mark', 'Sarah', 'Luce', 'John', 'Paula', 'Leo']

# %%
studenti.extend(['Philip', 'Jasmine'])
studenti
# Out:
# ['Ada', 'Mark', 'Sarah', 'Luce', 'John', 'Paula', 'Leo', 'Philip', 'Jasmine']

# %%
studenti.insert(1, 'Frances')
print(studenti)
# Out:
# ['Ada', 'Frances', 'Mark', 'Sarah', 'Luce', 'John', 'Paula', 'Leo', 'Philip', 'Jasmine']

# %%
studenti.remove('John')
print(studenti)
# Out:
# ['Ada', 'Frances', 'Mark', 'Sarah', 'Luce', 'Paula', 'Leo', 'Philip', 'Jasmine']

# %%
studenti.index('Luce')
# Out:
# 4

# %%
studenti.count('Luce')
# Out:
# 1

# %%
studenti.sort(key=None, reverse=False)
print(studenti)
studenti.sort(key=None, reverse=True)
print(studenti)
# Out:
# ['Ada', 'Frances', 'Jasmine', 'Leo', 'Luce', 'Mark', 'Paula', 'Philip', 'Sarah']
# ['Sarah', 'Philip', 'Paula', 'Mark', 'Luce', 'Leo', 'Jasmine', 'Frances', 'Ada']

# %%
studenti.reverse()
print(studenti)
# Out:
# ['Ada', 'Frances', 'Jasmine', 'Leo', 'Luce', 'Mark', 'Paula', 'Philip', 'Sarah']

# %%
scuola = 'Epicode'
print(scuola[0])
print(scuola[-2])
print(scuola[1:5])
# Out:
# E
# d
# pico

# %%
print(studenti[0])
print(studenti[-2])
print(studenti[0:3])
# Out:
# Ada
# Philip
# ['Ada', 'Frances', 'Jasmine']

# %%
print(scuola.upper())
print(scuola.lower())
print(scuola.strip())
print(scuola.replace('Epi', 'Happy'))
print(scuola.split('c'))
# Out:
# EPICODE
# epicode
# Epicode
# Happycode
# ['Epi', 'ode']
